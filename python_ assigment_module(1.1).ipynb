# %%
#first then one variable declared  then store a the all the value 
# second then  pass that 3 condition
 #  num<0
# num ==0
#num >0
# enter the number  greater than 0 then  numner is postive  # number is less than zero then number is negative number is equal 
#zero than number is equal 
# conditional statement using find this condition

# %%
#que_no:1

# write a python  program  tho check if a number is positive ,negative or zero 
number=int(input("enter the nnumber"))
if number>0:
    print(" tne number is positive")
elif number==0:
    print("the number is zero ")
else:
    print("your numbe is negative")

# %%
#Write a Python program to get the Factorial number of given number.

#factorial number is  that number to n number print  factorial  number  
#fact=5
# 5*3*4*3*2*1 =120
#that number to 1  in multiply
# fact  in variable  ma  factorial number  save thata jashe 
# fact *i
 # for i in range(1,num+1):
 #   fact *i
#  1*1=1
#  1*2=2
#   2*3=6
#   6*4=24
#   24*5=120
#  120*n number is fact number

# %%
#que_no:2


#Write a Python program to get the Factorial number of given number.
num= int(input("enter the number "))
fact = 1
if num<0:
    print("the number  is not a exist ")
if num==0:
    print("the factorial  of 0 is",1)
if num>0:
    for i in range (1,num+1):
        fact= fact*i
    print("the factorial of the given number is ",fact )

# %%
 # write the the fibinacci series in given wheather the number 
 # fibonacci series is the  
# first so 3 variable in the that program a,b,c  this store the value 
# fibonacci is = a=0 ,b=1, c= a+b 0+1=1, 1+1=2,1+2=3, 1+3=4,1+4=5,1+5=6,1+6=7
# a=0           
#b=1
#c=a+b 
# then condition 
#a=b            a=1       a=1          a=2         a=3
#b=c            b=1       b=2          b=3         b=5
#a=0            c=2       c=3          c=5        c=8
#b=1 
#c=a+b=1

# %%
#que_no:3

# write the the fibinacci series in given wheather the number 
a=0
b=1
sum=0
num = int(input("enter the number  to obtain squence "))
if  num==1:
    print(a)
else:
    print(a)
    print(b)
    for i in range(2,num):m
        sum+=i
        print(,"+",summ)

# %%
#Write python program that swap two number with temp variable and without temp variable.
#first so 4  variable are the declared in the program
# after temp variable 
#a=15
#b=45
#then third variable is temp variable
# temp variable is swapping that variable 

# then after that using temp variable
# a=45
#b=15

swapping variable is mean of  two  exchange the value
a=15----------a=45
b=45----------b=15

# %%
#que_no:4

#Write python program that swap two number with temp variable and without temp variable.
a= int(input("enter the number  of a:"))
b= int(input("enter the number of b:"))
print("before swapping a={} and b={}".format(a,b))

temp= a
a=b
b=temp
print("after the swapping a={}and b={}".format(a,b))

# %%
#write program wheather number is check  odd and even you can find this 
#1=first then  declared the variable and then user get that value 
#then pass the condition if number%2 
#then number is modulo  then use given number is return remainder  is 0 then number is odd
# then remainder  is 1,2,3 given number   is then nubmer is odd
# if number %2==0:   condition is  true      number is even
#even  condition is false  number is  od

# %%
#que_no:5

#write program wheather number is check  odd and even you can find this 
number=int(input("enter the number "))
if (number%2)==0:
    print("this number is even ")
else:
    print("this is number is odd ")

# %%
#que_no:6

# Write a Python program to sum of three given integers.However, if two  values are equal sum will be zero
x=int(input("enter the number of  x"))
y=int(input("enter the number   of y "))
z=int(input("enter the number of z"))
if x==y or y==z or z==x:
    print("sum is :",0)
else:
    print("sum is :",x+y+z)

# %%
# Write a Python program to sum of three given integers.However, if two  values are equal sum will be zero
# 1 .then 3 vairabel are the declared in this program and three variable initilize that int values
#  2 . then first then 3 condition is pass out that program 
#   x=y y=z z=x  then pass out the condition   after the one condition is same that values is return that (0)
#  second condition is that x+y+z are the 3 vsalues is diffrent  than return then sum

# %%
#que_no:7

#  Write a Python program that will return true if the two given integervalues  are equal or their sum or difference is 5.
x = (int(input("enter the number of ")))
y =(int(input("enter the number")))
if x==y and (x-y)==5 or (x+y)==5:
    print("true")
else:
    print("false")

# %%
# first then declare a 2 variables  user can input
#  after that paas out the condition then  if x==y or x-y=5 or x+y=5
# three mathi ek pan condition pass (true) thay to return (true)  karese
# else  return (false ) karese 
# logical operator no use and,or,not no operator no use thase .

# %%
#que_no:8

#Write a Python program to test whether a passed letter is a vowel or not
ch= input("enter the number: ")
if (ch=='a' or ch=='e' or ch=='i'or ch=='o' or ch=='u'):
    print("your character is  vowel",ch)
else:
    print("your character is consonant",ch)

# %%
# vowel= is the vyanjan character (a,e,i,o,u) is  charactr is  vowel 
# then other character is consonant  is return value
# if pass out the condition   if ch (a,e,i,o,u) then return character is vowel'
# if pass out the condition is false   your character is consonant

# %%
 #que_no:9
    
# Write a python program to sum of the first n positive integers
n= int(input("enter the number")) 
add_=(n*(n+1))/2
print("addition of the first ",n,"positive  integer ",add_)

# %%
# que_no :10
#  patern program in python 
for row in range(0,7):
    for col in range(0,7):
        if (row+col==3) or (col-row==3)  or (row+col==9) or (row-col==3):
            print("*",end="")
        else:
            print(" ",end="")
    print()
# Out:
#    *
#   * *
#  *   *
# *     *
#  *   *
#   * *
#    *

# %%
#que_no: 12

# write a progrsm in python wheather checjk the number in prime and not prime number
# prime = aevi value ke jene teni vade bhagata 1 remainder bachhe
# non prime = aevi value ke jene temi vadebhata 1 remander nai male 
num= int(input("enter the number "))
for i in range (2,num+1):
    if i<num  and num%i==0:
        print("not prime")
        break
    if i==num and num%i==0:
        print("prime")
        break
if num<=1 and num>0:
    print("prime")
if num==0:
    print("whole number ")
# Out:
# enter the number 3
# prime

# %%
 # que no :1
    
    #string function all the assign ment question 


#1)Write a Python program to calculate the length of a string
         # find a string calculate a string function built in method in  
    #len():=function using a any string length find be able
#str1="python is the everything "
#z=len(str1)
#print(z)



#input user enter the string then calculate the lengthb of string
str2=input("enter the string; ")
z=len(str2)
print("your string calclulate  character is the:",len(str2))

# %%
#que_no:2

#2)Write a Python program to count the number of characters character frequency in a string
text=input("enter the string ")
print("your string is",text)
char=input("enter the character of  occurance: ")
textlen=len(text)
sum=0
for i in range (textlen):
    if char==text[i]:
        sum=sum+1
print("your given character count is :")
print(sum)

# %%
# que no=3

#Write a Python program to count occurrences of a substring in a string.

#count function use for the calculate a given string  in calculate a  the substring occurance
#count syntax:= count(value,starting position ,ending position)
string1=input("enter the string ")
my_substring=input("enter substring")
count=string1.count(my_substring)
print("the count is:",count)

# second reet 
string=input("enter the string :")
c=input("enter the character in occurance in string :")
count=0
for i in string:
    if i==c:
        count+=1
print("substring occur in string count is ",c,"occurs ",count,"count")

# %%
# que_no:4

#Write a Python program to count the occurrences of each word in a given sentence
# enter the string  nakhavani 
#then  te string split finction  ni use thi string convert into list then after compilee the  for loop count karavana word ne 
# ascii function  use of the  all keyword of the all the word 


#string=input("enter the  string ")
#k=string.split()
#for ui in k:
 #   if ui.isascii():
  #      ans=k.count(ui)
   #     print(ui,':',ans)
        
        
# second method :-
# first of all given the string  and this  string
# second  je string mathi je word find karvano  chhe tene a string ma lakhavano   
#converted into  split function using converted to list
# second then you are  follow then loop  and 
# one variable declare kari devano  te variable noo value 0 rakhavani chhe 
#  first string== word thase to  count naam na variable ma  count vadhato jashe 
# then last string  na occur print karavi devana 
s=input("enter the string :")
s1=s.split(" ")
word=input("enter the word  entire the written this string occur substring")
count=0
for i in s1:
    if(i==word):
        count=count+1
print("occur of the word out the string is count is ",count)

# %%
#que_no:5

#Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.
# first all the enter the two given string  then swap the character 
# swap charcter karva mate :- replace method no use thase
# replce:= replace (tobe replced, replacement)
#replaced:=(jya repalce karvanu chhe te )
#replacement:=(jena vade replce ment karvanu chhe te )
k=input("enter the firststring :")
j=input("enter the  second string :")
x=k[0:2]
k=k.replace(k[0:2],j[0:2])
j=j.replace(j[0:2],x)
print("your first string is the :",k)
print("your second string is the :",j)

# %%
#que_no:6 

#Write a Python program to add 'ing' at the end of a given string (length
#should be at least 3). If the given string already ends with 'ing' then add 'ly'
#instead if the string length of the given string is less than 3, leave it
#unchanged.


#first of all the user input the string  then 
#1)check the condition string length  :[3<]  is the  condition is the true :(same print the string )
#2)check entire string  last 3 character [ing] is the comming in string  is the print in :(string  ing+ also add the (ly) the entire string ) 
#3)else condition is the false after than:=(string   length is [3>] after print the  string+ ing )

string=input("enter the string: ")
if len(string)<3:
    print(string)
elif string[-3:]=="ing":
    print(string+"ly")
que_    print(string+"ing")

# %%
# que_no:7

#Write a Python program to find the first appearance of the substring 'not'and 'poor' from a given string, if 'not' follows the 'poor', replace the whole 'not'...'poor'substring with 'good'. Return the resulting string.
#fisrt of all the enter the string under the word [using not and poor] word
#second thing entire the string find the postion of the the not :
#          two ways of the find the substring postiion
#            1)find method   2) index method
#  also find that a not and poor index
# simplify that condition is the  [postion of not <postion  of poor  print than
# 0 position to is postion_not  to print this string and 
# adding the  good key word 
str=input("enter the any string \n")
pos_not=str.find("not")
pos_poor=str.find("poor")
#print("not_pos is ",pos_not)
#print("poor_pos is ",pos_poor)
if pos_not<pos_poor:
    print(str[:pos_not]+"good")

# %%
#que_no:8

#Write a Python function that takes a list of words and returns the length of the longest one.
#  first of all the  user take a input string
# second user written this string can  converter to the list of (using function  split)
# user take a string than  find the length of this list using (len function)
#  after that pass out the for loop and try to find string length is  if the string (greater than 1) then 
# print the substring and his the lentgh(postion ) of that  substring

string=input("enter the string :")
z=string.split()
large=len(z)
for i in z:
    if(len(i)>1):
        w=z
        l=len(z)
print(z)
print("largest string is length is the ",l)

# %%
# que_no:9

#Write a Python function to reverses a string if its length is a multiple of 4
# fist of all the the enter the string given result that reverse
# entire the given the string find the len 
# string length finf  if  pass out that condition
# condition is the (string %4==0)
# condition is the true after that the result : string is reverse 
# output: reverse
str1=input(" enter the string given ordered to the riverse ")
if len(str1)%4==0:
    print(''.join(reversed(str1)))
else:
    print(str1)

# %%
#que_no:10

#Write a Python function to insert a string in the middle of a string
# first of all the  user take the input of the string
# string length find karava mate (len function no use karishu) after 
#  find karva mate middle index : all string/2
# ans = middle strinf length
# string in substring middle length karva mate (-1 index postion  start karvanu +2 postion atkavanu)
# tene print karavanu
string=input("enter the string ")
midd_index= int(len(string)/2)
print(midd_index)
print(string[midd_index-1:midd_index+2])

# %%
#que_no:11

#Write a Python program to get a string made of the first 2 and the last 2
#chars from a given a string. If the string length is less than 2, return instead
#of the empty string

#explanation
# first of all the user take a input  then
#one variable then declared his work:= (string  charcter is count)
#  after that  passed that a loop in  one by one eteration in string  character
# count  variable +1 increase that value
#second thing second variable is the declared 
# his work it  entire the string first [1,2 postion character print] and [-1,-2 character are the print]

string=input("enter the string")
count=0
for i in string:
    count=count+1
new=string[0:2]+string[count-2:count]
print("your string first two and last two character is the:\n ",new)

# %%
#que_no:12

#Sample String: w3resource'
# Expected Result: 'w3ce'
#  Sample String: 'w3'
# Expected Result: 'w3w3'
#  Sample String: ' w'
# Expected Result: Empty String

# Sample String: w3resource'
# Expected Result: 'w3ce'

 # Sample String: 'w3'
# Expected Result: 'w3w3'



# explanation
# first of the all the user can take a input
# two variable are declare # first variable (2 index print karese)  # second varaible: (last 2 index occur character print )
#third variable are the declared  this work  first+ second print this string
# if  find this length this string pass out the  3 condition
 #                     string ni index (less than 2)         to string  ne empty print karvani 
#                      string ni index (string==2)            to  tej string two time repeat karine print karvani 
#                      strinf ni index (greater than 2)     to  first ane second ni string print karvani

# %%
# que_no:13:-program
str1=input("enter the string ")
first=str1[0:2]
second=str1[-2:]
res=first+second
if len(str1)<2:
    print("your string is empty ")
elif len(str1)==2:
    print(str1*2)
elif len(str1)>=3:
    print(first,second,sep='')
